# %% [markdown]
# # TotalSegmentator: whole-body CT segmentation
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/fideus-labs/KonfAI/blob/main/examples/TotalSegmentator/TotalSegmentator_demo.ipynb)
#
# **Run all the cells.** `totalsegmentator-konfai` is a KonfAI **app**: a published model on the Hugging Face Hub
# ([`VBoussot/TotalSegmentator-KonfAI`](https://huggingface.co/VBoussot/TotalSegmentator-KonfAI)) wrapped behind one command, for whole-body **CT segmentation**.
# No training, no config to write: the app carries its own.
#
# The model is downloaded on the first run (a few hundred MB) and a **GPU is strongly recommended**; on
# Colab pick *Runtime > Change runtime type > GPU*.

# %%
# Setup: find KonfAI (cloning it on Colab), install what is missing, load the notebook helpers.
import subprocess
import sys
from pathlib import Path

if "google.colab" in sys.modules:
    REPO_DIR = Path("/content/KonfAI")
    if not REPO_DIR.exists():
        subprocess.run(["git", "clone", "--depth", "1", "https://github.com/fideus-labs/KonfAI", str(REPO_DIR)], check=True)
else:
    REPO_DIR = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / "examples").is_dir())
sys.path.insert(0, str(REPO_DIR / "examples"))

from konfai_demo import read, run, setup, show

EXAMPLE_DIR, DATASET_DIR, DEVICE = setup(REPO_DIR, "TotalSegmentator", ("konfai", f"{REPO_DIR}[imaging]"), ("konfai_apps", str(REPO_DIR / "konfai-apps")), ("totalsegmentator_konfai", str(REPO_DIR / "apps" / "totalsegmentator")), "SimpleITK", "huggingface_hub", "matplotlib")

# %% [markdown]
# ## 1. One public demo case
#
# A single CT volume from the public demo dataset.

# %%
import shutil

from huggingface_hub import snapshot_download

if not any(DATASET_DIR.glob("*/CT.mha")):
    snapshot_download("VBoussot/konfai-demo", repo_type="dataset", allow_patterns="Segmentation/**", local_dir=str(DATASET_DIR))
    for case in (DATASET_DIR / "Segmentation").iterdir():
        shutil.move(str(case), DATASET_DIR / case.name)
    shutil.rmtree(DATASET_DIR / "Segmentation")
    shutil.rmtree(DATASET_DIR / ".cache", ignore_errors=True)

CASES = sorted(path.name for path in DATASET_DIR.iterdir() if path.is_dir())
print(len(CASES), "cases:", ", ".join(CASES))

# %% [markdown]
# ## 2. Look at the input CT

# %%
import numpy as np

case = DATASET_DIR / CASES[0]
INPUT_PATH = case / "CT.mha"
image = read(INPUT_PATH).astype(np.float32)
print(case.name, "| shape:", image.shape)

low, high = np.percentile(image, [1, 99])


def window(index):
    """One slice, clipped to a robust intensity window so a few extreme voxels do not wash it out."""
    return np.clip(image[index], low, high)


MID = image.shape[0] // 2
show([(f"CT, slice {MID}", window(MID), "gray")])

# %% [markdown]
# ## 3. Run the model
#
# One command. KonfAI does the rest: it reads the volume lazily, runs the network patch by patch, and
# reassembles the label map with overlap blending, never loading the full volume into memory.
#
# ```bash
# totalsegmentator-konfai segment total -i input.mha -o ./Output/ --gpu 0
# ```

# %%
OUTPUT_DIR = EXAMPLE_DIR / "Output"

run("totalsegmentator-konfai", "segment", "total", "-i", str(INPUT_PATH), "-o", str(OUTPUT_DIR), *DEVICE)
print("wrote:", *sorted(path.name for path in OUTPUT_DIR.rglob("*.mha")))

# %% [markdown]
# ## 4. The result
#
# The label map the app produced, on the input grid.

# %%
import numpy as np

produced = sorted(OUTPUT_DIR.rglob("*.mha"))
result = read(produced[0])
print(produced[0].relative_to(OUTPUT_DIR), "|", result.shape, "| values:", np.unique(result)[:12], "...")

# The slice the model filled most, so the figure lands where there is something to see.
SLICE = int(np.argmax((result > 0).sum(axis=(1, 2))))
show([
    ("input CT", window(SLICE), "gray"),
    ("segmentation", window(SLICE), "gray", result[SLICE]),
])

# %% [markdown]
# ## What to change next
#
# - **your own volume**: point `-i` at any `.mha` / `.nii.gz`, or at an OME-Zarr or DICOM directory;
#   KonfAI detects the store format on read.
# - **score it**: `totalsegmentator-konfai eval total -i input.mha --gt reference.mha -o Output`.
# - **everything at once**: `totalsegmentator-konfai pipeline ...` chains inference and evaluation. This bundle ships no uncertainty workflow, so unlike the other apps there is no `-uncertainty` step to chain.
# - **see how an app is built**: `apps/totalsegmentator/` in this repo is the whole wrapper.
